# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as dpd
df = pd.read_csv(r'C:\Users\paras\OneDrive\Desktop\Vs Code\Python\diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load DataFrame (Replace 'your_file.csv' with the actual file path)
df = pd.read_csv(r'C:\Users\paras\OneDrive\Desktop\Vs Code\Python\diabetes.csv')  

# Clean column names (remove spaces, convert to lowercase)
df.columns = df.columns.str.strip().str.lower()

# Check if 'glucose' exists
if 'glucose' in df.columns:
    # Drop NaN values
    glucose_data = df['glucose'].dropna()

    # Plot histogram
    plt.figure(figsize=(8, 5))
    sns.histplot(glucose_data, bins=15, kde=True, color='blue', edgecolor='black')

    # Add mean line
    mean_glucose = glucose_data.mean()
    plt.axvline(mean_glucose, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_glucose:.2f}')

    # Titles and labels
    plt.title('Histogram of Glucose', fontsize=14)
    plt.xlabel('Glucose', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.legend()
    plt.show()

else:
    print("Error: Column 'glucose' not found in DataFrame!")

# %%
sns.scatterplot(x='age',y='bmi',data=df,hue='pregnancies')
plt.title('Scatter Plot of Age vs Glucose')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Corrected x-axis to 'Outcome' (not 'diabetes')
sns.boxplot()  # Added the missing boxplot function

plt.title('Box Plot of Glucose by Diabetes Outcome')
plt.xlabel('Diabetes (0 = No, 1 = Yes)')
plt.ylabel('Glucose')
plt.show()

# %%
plt.figure(figsize=(10,6))
correlation=df.corr()
sns.heatmap(correlation,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt

# Print column names to check for issues
print("Column Names:", df.columns)

# Standardize column names (strip spaces & convert to lowercase)
df.columns = df.columns.str.strip().str.lower()

# Check for correct column name
if 'outcome' in df.columns:
    diabetes_count = df['outcome'].value_counts()
    print(diabetes_count)

    # Create pie chart
    plt.pie(diabetes_count, labels=['No Diabetes', 'Diabetes'], autopct='%1.1f%%', colors=['lightblue', 'orange'])
    plt.title('Diabetes Distribution')
    plt.show()
else:
    print("Error: Column 'Outcome' not found in DataFrame!")
# Out:
# Column Names: Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')
# outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df1=pd.read_csv(r'C:\Users\paras\OneDrive\Desktop\Vs Code\Python\iris.csv')
df1.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
print(df1.columns)

print(df.columns)
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore


z_scores = df.apply(zscore)


outliers = (np.abs(z_scores) > 3)


print("Z-scores:\n", z_scores)
print("\nOutliers (True means it's an outlier):\n", outliers)


outlier_values = df[outliers]
print("\nOutlier Values:\n", outlier_values)
# Out:
# Z-scores:
#       pregnancies   glucose  bloodpressure  skinthickness   insulin       bmi  \
# 0       0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1      -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2       1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3      -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4      -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.622642       0.356432       1.722735  0.870031  0.115169
# 764    -0.547919  0.034598       0.046245       0.405445 -0.692891  0.610154
# 765     0.342981  0.003301       0.149641       0.154533  0.279594 -0.735190
# 766    -0.844885  0.159787      -0.470732      -1.288212 -0.692891 -0.240205
# 767    -0.844885 -0.873019       0.046245       0.656358 -0.692891 -0.202129
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns




Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)


IQR = Q3 - Q1


outliers = ((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR)))


print("Outlier Values:\n", df1[outliers])


plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title('Boxplot for Outlier Detection')
plt.show()
# Out:
# Outlier Values:
#       5.1  3.5  1.4  0.2 Iris-setosa
# 0    NaN  NaN  NaN  NaN         NaN
# 1    NaN  NaN  NaN  NaN         NaN
# 2    NaN  NaN  NaN  NaN         NaN
# 3    NaN  NaN  NaN  NaN         NaN
# 4    NaN  NaN  NaN  NaN         NaN
# ..   ...  ...  ...  ...         ...
# 144  NaN  NaN  NaN  NaN         NaN
# 145  NaN  NaN  NaN  NaN         NaN
# 146  NaN  NaN  NaN  NaN         NaN
# 147  NaN  NaN  NaN  NaN         NaN
# 148  NaN  NaN  NaN  NaN         NaN
#
# [149 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# Load dataset (assuming it's already loaded as df)
# df = pd.read_csv("your_file.csv")  # Uncomment this if you need to load the dataset

# Ensure column names are lowercase for consistency
df.columns = df.columns.str.lower()

# Print column names to verify
print("Column Names:", df.columns)

# Check if 'outcome' column exists
if 'outcome' not in df.columns:
    raise KeyError("Column 'outcome' not found in dataset. Check column names.")

# Feature selection
X = df[['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 
        'insulin', 'bmi', 'diabetespedigreefunction', 'age']]
y = df[['outcome']]

# Split dataset into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print dataset shapes
print("Training Set Shape:", X_train.shape)
print("Testing Set Shape:", X_test.shape)

# Boxplot for Glucose by Diabetes Outcome
plt.figure(figsize=(12, 6))
sns.boxplot(x='outcome', y='glucose', data=df)
plt.title('Box Plot of Glucose by Diabetes Outcome')
plt.xlabel('Diabetes (0 = No, 1 = Yes)')
plt.ylabel('Glucose')
plt.show()

# Pie chart for diabetes distribution
diabetes_count = df['outcome'].value_counts()
plt.pie(diabetes_count, labels=['No Diabetes', 'Diabetes'], autopct='%1.1f%%', startangle=90, colors=['lightblue', 'orange'])
plt.title('Diabetes Distribution')
plt.show()
# Out:
# Column Names: Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')
# Training Set Shape: (537, 8)
# Testing Set Shape: (231, 8)

# %%
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(X_train)

sum(var_thres.get_support())

len(X_train.columns[var_thres.get_support()])

constant_columns = [column for column in X_train.columns
                    if column not in X_train.columns[var_thres.get_support()]]

print(len(constant_columns))
# Out:
# 0

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))

corr_features
# Out:
# set()

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 668            6       98             58             33      190  34.0
# 324            2      112             75             32        0  35.7
# 624            2      108             64              0        0  30.8
# 690            8      107             80              0        0  24.6
# 473            7      136             90              0        0  29.9
# ..           ...      ...            ...            ...      ...   ...
# 619            0      119              0              0        0  32.4
# 198            4      109             64             44       99  34.8
# 538            0      127             80             37      210  36.3
# 329            6      105             70             32       68  30.8
# 302            5       77             82             41       42  35.8
#
#      diabetespedigreefunction  age
# 668                     0.430   43
# 324                     0.148   21
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from scipy.stats import chi2_contingency, f_oneway
from math import log2

# Ensure column names are lowercase and strip spaces
df.columns = df.columns.str.lower().str.strip()

# Check available columns
print("Available Columns:", df.columns)

# Define feature and target columns
feature_cols = ['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 
                'insulin', 'bmi', 'diabetespedigreefunction', 'age']
target_col = 'outcome'

# Ensure all required columns exist
missing_cols = [col for col in feature_cols + [target_col] if col not in df.columns]
if missing_cols:
    raise KeyError(f"Missing columns in the dataset: {missing_cols}")

# Separate features and target
X = df[feature_cols]
y = df[target_col]  # Keep y as a 1D array

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Function to calculate entropy
def entropy(y):
    p_pos = np.sum(y == 1) / len(y)
    p_neg = 1 - p_pos
    if p_pos == 0 or p_neg == 0:  # Avoid log(0)
        return 0
    return -p_pos * log2(p_pos) - p_neg * log2(p_neg)

# Function to calculate information gain
def information_gain(X, feature, y):
    total_entropy = entropy(y)

    # Get unique values of the feature
    values = X[feature].unique()

    weighted_entropy = 0
    for value in values:
        subset_y = y[X[feature] == value]
        weighted_entropy += (len(subset_y) / len(y)) * entropy(subset_y)

    return total_entropy - weighted_entropy

# Pearson's Correlation Coefficient
correlation_matrix = X.corr()
print("Pearson's Correlation Coefficients:\n", correlation_matrix)

# Select only categorical features for Chi-Square test
categorical_features = ['pregnancies']  # Add more if they are categorical

# Convert continuous features into categorical bins for Chi-Square
for feature in ['glucose', 'bloodpressure', 'skinthickness', 'insulin', 'bmi', 'age']:
    X[feature + '_bin'] = pd.cut(X[feature], bins=5, labels=False)

# Update categorical features list with new binned columns
categorical_features += [feature + '_bin' for feature in ['glucose', 'bloodpressure', 'skinthickness', 'insulin', 'bmi', 'age']]

# Chi-Square Test for categorical features
for feature in categorical_features:
    contingency_table = pd.crosstab(X[feature], y)
    chi2, p, _, _ = chi2_contingency(contingency_table)
    print(f"Chi-Square test for {feature}: p-value = {p:.4f}")

# ANOVA test for continuous features
for feature in feature_cols:
    f_stat, p_value = f_oneway(X[y == 0][feature], X[y == 1][feature])
    print(f"ANOVA test for {feature}: p-value = {p_value:.4f}")

# Calculate Information Gain for each feature
print("\nInformation Gain for each feature:")
for feature in feature_cols:
    ig = information_gain(X_train, feature, y_train)
    print(f"Information Gain for {feature}: {ig:.4f}")

# Model training and accuracy comparison
# Logistic Regression
logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train, y_train)
y_pred_logreg = logreg.predict(X_test)
logreg_accuracy = accuracy_score(y_test, y_pred_logreg)

# K-Nearest Neighbors
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
knn_accuracy = accuracy_score(y_test, y_pred_knn)

# Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
rf_accuracy = accuracy_score(y_test, y_pred_rf)

# Print out the accuracies of all models
print("\nModel Accuracy Comparison:")
print(f"Logistic Regression Accuracy: {logreg_accuracy:.4f}")
print(f"K-Nearest Neighbors Accuracy: {knn_accuracy:.4f}")
print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
# Out:
# Available Columns: Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')
# Pearson's Correlation Coefficients:
#                            pregnancies   glucose  bloodpressure  skinthickness  \
# pregnancies                  1.000000  0.129459       0.141282      -0.081672
# glucose                      0.129459  1.000000       0.152590       0.057328
# bloodpressure                0.141282  0.152590       1.000000       0.207371
# skinthickness               -0.081672  0.057328       0.207371       1.000000
# insulin                     -0.073535  0.331357       0.088933       0.436783
# bmi                          0.017683  0.221071       0.281805       0.392573
# diabetespedigreefunction    -0.033523  0.137337       0.041265       0.183928
# age                          0.544341  0.263514       0.239528      -0.113970
#
# ...
